# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Face Deduction

# %% [markdown]
# backends =["opencv","ssd","dlib","mtcnn","retinaface","mediapipe"]

# %%
face=DeepFace.detectFace(r"C:\Users\chemi\Desktop\Data_For_face_recognistion\Face_deduction_training\yogi ji\yogi ji_14.jpg",target_size=(244,244),detector_backend='opencv')
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %%
face.shape
# Out:
# (244, 244, 3)

# %%
plt.imshow(face)
