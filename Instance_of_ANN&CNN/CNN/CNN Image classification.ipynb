# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
(x_train,y_train),(x_test,y_test) = datasets.cifar10.load_data()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
pd.DataFrame(x_train[0][0])
# Out:
#       0    1    2
# 0    59   62   63
# 1    43   46   45
# 2    50   48   43
# 3    68   54   42
# 4    98   73   52
# 5   119   91   63
# 6   139  107   75
# 7   145  110   80
# 8   149  117   89
# 9   149  120   93
# 10  131  103   77
# 11  125   99   76
# 12  142  115   91
# 13  144  112   86
# 14  137  105   79
# 15  129   97   71
# 16  137  106   79
# 17  134  106   76
# 18  124   97   64
# 19  139  113   78
# 20  139  112   75
# 21  133  105   69
# 22  136  105   74
# 23  139  108   77
# 24  152  120   89
# 25  163  131  100
# 26  168  136  108
# 27  159  129  102
# 28  158  130  104
# 29  158  132  108
# 30  152  125  102
# 31  148  124  103

# %%
classes=["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
y_train[0]
# Out:
# array([6], dtype=uint8)

# %%
class_name= ["airplane",'automobile', 'bird']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\chemi\Desktop\enviroments\myml\1-Notebooks_python\All Scripts\Deep_learning_model\Instance_of_ANN&CNN\CNN\CNN Image classification.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/chemi/Desktop/enviroments/myml/1-Notebooks_python/All%20Scripts/Deep_learning_model/Instance_of_ANN%26CNN/CNN/CNN%20Image%20classification.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     plt.imshow(x[index])
#       <a href='vscode-notebook-cell:/c%3A/Users/chemi/Desktop/enviroments/myml/1-Notebooks_python/All%20Scripts/Deep_learning_model/Instance_of_ANN%26CNN/CNN/CNN%20Image%20classification.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     plt.xlabel(classes[y[index]])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chemi/Desktop/enviroments/myml/1-Notebooks_python/All%20Scripts/Deep_learning_model/Instance_of_ANN%26CNN/CNN/CNN%20Image%20classification.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> plot_sample(x_train,y_train,1)
#
# c:\Users\chemi\Desktop\enviroments\myml\1-Notebooks_python\All Scripts\Deep_learning_model\Instance_of_ANN&CNN\CNN\CNN Image classification.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/chemi/Desktop/enviroments/myml/1-Notebooks_python/All%20Scripts/Deep_learning_model/Instance_of_ANN%26CNN/CNN/CNN%20Image%20classification.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(15,2))
#       <a href='vscode-notebook-cell:/c%3A/Users/chemi/Desktop/enviroments/myml/1-Notebooks_python/All%20Scripts/Deep_learning_model/Instance_of_ANN%26CNN/CNN/CNN%20Image%20classification.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(x[index])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chemi/Desktop/enviroments/myml/1-Notebooks_python/All%20Scripts/Deep_learning_model/Instance_of_ANN%26CNN/CNN/CNN%20Image%20classification.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel(classes[y[index]])
#
# TypeError: only integer scalar arrays can be converted to a scalar index
